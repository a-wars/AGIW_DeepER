# %% [markdown]
# # Testing DeepER
#
# ### Import libraries

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import sys
sys.path.append('../')

# %%
import time
import os
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.models import load_model
import matplotlib.pyplot as plt
import seaborn as sns
from deeper_model import build_model
from deeper_utils import preprocess_data
from custom_callbacks import Metrics
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Read the dataset

# %%
trainData, testData, valData, embeddingMatrix, wordsWithNoEmbeddings = preprocess_data(
    'DBLP-ACM', baseDir = '../input/deeper/deeper', maxSequenceLength=100)

# %% [markdown]
# Printing out words with no embeddings in GloVe

# %%
PRINT_RANGE = 30

if len(wordsWithNoEmbeddings) < PRINT_RANGE:
    PRINT_RANGE = len(wordsWithNoEmbeddings)

if PRINT_RANGE > 0:   
    for i in range(PRINT_RANGE):
        print(wordsWithNoEmbeddings[i])

print('...')
print("There are {} words with no embeddings in GloVe".format(len(wordsWithNoEmbeddings)))
# Out:
# sigmod
# vldb
# ramakrishnan
# surajit
# seshadri
# suciu
# divesh
# kyuseok
# kriegel
# aberer
# lakshmanan
# garofalakis
# abiteboul
# florescu
# hellerstein
# silberschatz
# pirahesh
# haritsa
# ioannidis
# moerkotte
# faloutsos
# sarawagi
# chakrabarti
# jayavel
# shanmugasundaram
# gehrke
# shekita
# viswanath
# poosala
# syan
# ...
# There are 2196 words with no embeddings in GloVe

# %% [markdown]
# Print embedding matrix shape

# %%
embeddingMatrix.shape
# Out:
# (7850, 300)

# %%
leftTableTrainData, rightTableTrainData, trainLabels = trainData
leftTableTestData, rightTableTestData, testLabels = testData
leftTableValData, rightTableValData, valLabels = valData

# %% [markdown]
# Print training set size

# %%
print(leftTableTrainData.shape)
print(rightTableTrainData.shape)
# Out:
# (7417, 100)
# (7417, 100)

# %% [markdown]
# Print test set size

# %%
print(leftTableTestData.shape)
print(rightTableTestData.shape)
# Out:
# (2473, 100)
# (2473, 100)

# %% [markdown]
# Print validation set size

# %%
print(leftTableValData.shape)
print(rightTableValData.shape)
# Out:
# (2473, 100)
# (2473, 100)

# %% [markdown]
# ### Build the DeepER model

# %%
model = build_model(embeddingMatrix, lstmUnits=75, denseUnits=[16, 8], lstm_dropout=0.1, mask_zero=True, maxSequenceLength=100)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 100)          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 100)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 100, 300)     2355000     input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 150)          225600      embedding_1[0][0]
#                                                                  embedding_1[1][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 150)          0           bidirectional_1[0][0]
#                                                                  bidirectional_1[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           2416        subtract_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            136         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            18          dense_2[0][0]
# ==================================================================================================
# Total params: 2,583,170
# Trainable params: 2,583,170
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Plot DeepER architecture

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ### Training

# %%
start_time = time.time()

metricsHistory = Metrics()
history = model.fit([leftTableTrainData,
           rightTableTrainData],
          trainLabels,
          batch_size=16,
          epochs=20,
          callbacks=[metricsHistory],
          validation_data=([leftTableValData,
                            rightTableValData],
                           valLabels))

elapsed_time = time.time() - start_time
t = time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
print('Elapsed time (learning):', t)
# Out:
# Train on 7417 samples, validate on 2473 samples
# Epoch 1/20
# 7417/7417 [==============================] - 374s 50ms/step - loss: 0.1670 - acc: 0.9380 - val_loss: 0.0621 - val_acc: 0.9871
# Updating best model
# Current best model comes from epoch 0
# val_f1:0.96	val_precision: 0.95	val_recall: 0.98
#
# Epoch 2/20
# 7417/7417 [==============================] - 368s 50ms/step - loss: 0.0581 - acc: 0.9840 - val_loss: 0.0389 - val_acc: 0.9883
# Updating best model
# Current best model comes from epoch 1
# val_f1:0.97	val_precision: 0.94	val_recall: 0.99
#
# Epoch 3/20
# 7417/7417 [==============================] - 366s 49ms/step - loss: 0.0329 - acc: 0.9911 - val_loss: 0.0440 - val_acc: 0.9846
# val_f1:0.96	val_precision: 0.93	val_recall: 0.99
#
# Epoch 4/20
# 7417/7417 [==============================] - 367s 50ms/step - loss: 0.0204 - acc: 0.9953 - val_loss: 0.0452 - val_acc: 0.9834
# val_f1:0.96	val_precision: 0.92	val_recall: 0.99
#
# Epoch 5/20
# 7417/7417 [==============================] - 368s 50ms/step - loss: 0.0128 - acc: 0.9974 - val_loss: 0.0373 - val_acc: 0.9891
# Updating best model
# Current best model comes from epoch 4
# val_f1:0.97	val_precision: 0.95	val_recall: 0.99
#
# Epoch 6/20
# 7417/7417 [==============================] - 367s 49ms/step - loss: 0.0114 - acc: 0.9972 - val_loss: 0.0364 - val_acc: 0.9871
# val_f1:0.96	val_precision: 0.94	val_recall: 0.99
#
# Epoch 7/20
# 7417/7417 [==============================] - 366s 49ms/step - loss: 0.0099 - acc: 0.9973 - val_loss: 0.0368 - val_acc: 0.9879
# val_f1:0.97	val_precision: 0.94	val_recall: 0.99
#
# Epoch 8/20
# 7417/7417 [==============================] - 367s 49ms/step - loss: 0.0079 - acc: 0.9980 - val_loss: 0.0313 - val_acc: 0.9907
# Updating best model
# Current best model comes from epoch 7
# val_f1:0.97	val_precision: 0.96	val_recall: 0.99
#
# Epoch 9/20
# 7417/7417 [==============================] - 369s 50ms/step - loss: 0.0072 - acc: 0.9981 - val_loss: 0.0326 - val_acc: 0.9911
# Updating best model
# Current best model comes from epoch 8
# val_f1:0.98	val_precision: 0.96	val_recall: 0.99
#
# Epoch 10/20
# 7417/7417 [==============================] - 368s 50ms/step - loss: 0.0079 - acc: 0.9980 - val_loss: 0.0353 - val_acc: 0.9895
# val_f1:0.97	val_precision: 0.95	val_recall: 0.99
#
# Epoch 11/20
# 7417/7417 [==============================] - 366s 49ms/step - loss: 0.0066 - acc: 0.9981 - val_loss: 0.0353 - val_acc: 0.9891
# val_f1:0.97	val_precision: 0.96	val_recall: 0.98
#
# Epoch 12/20
# 7417/7417 [==============================] - 367s 49ms/step - loss: 0.0071 - acc: 0.9978 - val_loss: 0.0391 - val_acc: 0.9891
# val_f1:0.97	val_precision: 0.95	val_recall: 0.99
#
# Epoch 13/20
# 5952/7417 [=======================>......] - ETA: 1:04 - loss: 0.0075 - acc: 0.9980

# %% [markdown]
# ### Plot loss

# %%
history_dict = history.history

acc = history_dict['acc']
val_acc = history_dict['val_acc']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12,12))
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
# ### Plot accuracy

# %%
plt.figure(figsize=(12,12))
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'g', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Plot precision (for matching records)

# %%
plt.figure(figsize=(12,12))
valPrecision = metricsHistory.valPrecisionHistory
plt.plot(epochs, valPrecision, 'g', label='Validation precision')
plt.title('Validation precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()

# %% [markdown]
# ### Plot recall (for matching records)

# %%
plt.figure(figsize=(12,12))
valRecall = metricsHistory.valRecallHistory
plt.plot(epochs, valRecall, 'g', label='Validation recall')
plt.title('Validation recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()

# %% [markdown]
# ### Plot F-measure (for matching records)

# %%
plt.figure(figsize=(12,12))
valFMeasure = metricsHistory.valFMeasureHistory
plt.plot(epochs, valFMeasure, 'g', label='Validation f-measure')
plt.title('Validation f-measure')
plt.xlabel('Epochs')
plt.ylabel('F-measure')
plt.legend()

# %% [markdown]
# ### Evaluating the model trained on 20 epoch
#
# ### Predict labels on test data

# %%
predictedLabels = model.predict(x=[leftTableTestData, rightTableTestData])
predictedBinaryLabels = predictedLabels.argmax(axis=1)
testBinaryLabels = testLabels.argmax(axis=1)

# %% [markdown]
# ### Compute confusion matrix

# %%
cm = confusion_matrix(testBinaryLabels, predictedBinaryLabels)
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(cm, annot=True, ax = ax, fmt='g', cmap='Blues')

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['non matching', 'matching'])
ax.yaxis.set_ticklabels(['non matching', 'matching'])
# Out:
# [Text(0, 0.5, 'non matching'), Text(0, 1.5, 'matching')]

# %% [markdown]
# ### Compute metrics

# %%
precisionValues, recallValues, fMeasureValues, supportValues = precision_recall_fscore_support(testBinaryLabels, predictedBinaryLabels)

NUM_LABELS = len(precisionValues)

row_format ="{:>15}" * 5
print(row_format.format('Label','Precision', 'Recall', 'F-measure', 'Support'))

for i in range(NUM_LABELS):
    fMeasure = fMeasureValues[i]
    
    if fMeasure is None:
        fMeasure = 0.0
        
    print(row_format.format(i, round(precisionValues[i], 2), round(recallValues[i], 2), round(fMeasureValues[i],2), round(supportValues[i],2)))
# Out:
#           Label      Precision         Recall      F-measure        Support
#               0            1.0           0.98           0.99           2029
#               1           0.93           0.98           0.96            444

# %% [markdown]
# ---
#
# ### Evaluating the "best" model
#
# ### Loading the model

# %%
bestModel = load_model('best-model.h5')

# %% [markdown]
# ### Predict labels on test data

# %%
predictedLabels = bestModel.predict(x=[leftTableTestData, rightTableTestData])
predictedBinaryLabels = predictedLabels.argmax(axis=1)

# %% [markdown]
# ### Compute confusion matrix

# %%
cm = confusion_matrix(testBinaryLabels, predictedBinaryLabels)
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(cm, annot=True, ax = ax, fmt='g', cmap='Blues')

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['non matching', 'matching'])
ax.yaxis.set_ticklabels(['non matching', 'matching'])
# Out:
# [Text(0, 0.5, 'non matching'), Text(0, 1.5, 'matching')]

# %% [markdown]
# ### Compute metrics

# %%
precisionValues, recallValues, fMeasureValues, supportValues = precision_recall_fscore_support(testBinaryLabels, predictedBinaryLabels)

print(row_format.format('Label','Precision', 'Recall', 'F-measure', 'Support'))

for i in range(NUM_LABELS):
    fMeasure = fMeasureValues[i]
    
    if fMeasure is None:
        fMeasure = 0.0
        
    print(row_format.format(i, round(precisionValues[i], 2), round(recallValues[i], 2), round(fMeasureValues[i],2), round(supportValues[i],2)))
# Out:
#           Label      Precision         Recall      F-measure        Support
#               0            1.0           0.99           0.99           2029
#               1           0.95           0.98           0.97            444
