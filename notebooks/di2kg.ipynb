# %% [markdown]
# # Testing DeepER
#
# ### Import libraries

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import sys
sys.path.append('../')

# %%
import time
import os
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.models import load_model
import matplotlib.pyplot as plt
import seaborn as sns
from deeper_model import build_model
from deeper_utils import preprocess_data
from custom_callbacks import Metrics
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Read the dataset

# %%
# !ls ../input/deeperdatasets/datasets/DI2KG
# Out:
# DI2KG_test.csv	DI2KG_train.csv  DI2KG_valid.csv

# %%
trainData, testData, valData, embeddingMatrix, wordsWithNoEmbeddings = preprocess_data(
    'DI2KG', baseDir = '../input', embeddingDir='fasttextmodel', datasetDir='deeperdatasets/datasets', maxSequenceLength=100)

# %% [markdown]
# Printing out words with no embeddings in GloVe

# %%
PRINT_RANGE = 30

if len(wordsWithNoEmbeddings) < PRINT_RANGE:
    PRINT_RANGE = len(wordsWithNoEmbeddings)

if PRINT_RANGE > 0:   
    for i in range(PRINT_RANGE):
        print(wordsWithNoEmbeddings[i])

print('...')
print("There are {} words with no embeddings in GloVe".format(len(wordsWithNoEmbeddings)))
# Out:
# ...
# There are 0 words with no embeddings in GloVe

# %% [markdown]
# Print embedding matrix shape

# %%
embeddingMatrix.shape
# Out:
# (672, 300)

# %%
leftTableTrainData, rightTableTrainData, trainLabels = trainData
leftTableTestData, rightTableTestData, testLabels = testData
leftTableValData, rightTableValData, valLabels = valData

# %% [markdown]
# Print training set size

# %%
print(leftTableTrainData.shape)
print(rightTableTrainData.shape)
# Out:
# (4195, 100)
# (4195, 100)

# %% [markdown]
# Print test set size

# %%
print(leftTableTestData.shape)
print(rightTableTestData.shape)
# Out:
# (524, 100)
# (524, 100)

# %% [markdown]
# Print validation set size

# %%
print(leftTableValData.shape)
print(rightTableValData.shape)
# Out:
# (525, 100)
# (525, 100)

# %% [markdown]
# ### Build the DeepER model

# %%
model = build_model(embeddingMatrix, lstmUnits=75, denseUnits=[16, 8], lstm_dropout=0.1, mask_zero=True, maxSequenceLength=100)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 100)          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 100)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 100, 300)     201600      input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 150)          225600      embedding_1[0][0]
#                                                                  embedding_1[1][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 150)          0           bidirectional_1[0][0]
#                                                                  bidirectional_1[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           2416        subtract_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            136         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            18          dense_2[0][0]
# ==================================================================================================
# Total params: 429,770
# Trainable params: 429,770
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Plot DeepER architecture

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ### Training

# %%
start_time = time.time()

metricsHistory = Metrics()
history = model.fit([leftTableTrainData,
           rightTableTrainData],
          trainLabels,
          batch_size=16,
          epochs=20,
          callbacks=[metricsHistory],
          validation_data=([leftTableValData,
                            rightTableValData],
                           valLabels))

elapsed_time = time.time() - start_time
t = time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
print('Elapsed time (learning):', t)
# Out:
# Train on 4195 samples, validate on 525 samples
# Epoch 1/20
# 4195/4195 [==============================] - 206s 49ms/step - loss: 0.0509 - acc: 0.9874 - val_loss: 0.0049 - val_acc: 0.9981
# Updating best model
# Current best model comes from epoch 0
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 2/20
# 4195/4195 [==============================] - 200s 48ms/step - loss: 0.0047 - acc: 0.9983 - val_loss: 0.0013 - val_acc: 1.0000
# Updating best model
# Current best model comes from epoch 1
# val_f1:1.0	val_precision: 1.0	val_recall: 1.0
#
# Epoch 3/20
# 4195/4195 [==============================] - 199s 47ms/step - loss: 7.9106e-04 - acc: 0.9995 - val_loss: 0.0138 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 4/20
# 4195/4195 [==============================] - 203s 48ms/step - loss: 0.0020 - acc: 0.9998 - val_loss: 0.0091 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 5/20
# 4195/4195 [==============================] - 200s 48ms/step - loss: 4.8805e-05 - acc: 1.0000 - val_loss: 0.0107 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 6/20
# 4195/4195 [==============================] - 199s 47ms/step - loss: 2.0640e-05 - acc: 1.0000 - val_loss: 0.0113 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 7/20
# 4195/4195 [==============================] - 197s 47ms/step - loss: 1.3953e-05 - acc: 1.0000 - val_loss: 0.0117 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 8/20
# 4195/4195 [==============================] - 197s 47ms/step - loss: 9.6870e-06 - acc: 1.0000 - val_loss: 0.0120 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 9/20
# 4195/4195 [==============================] - 197s 47ms/step - loss: 8.3765e-06 - acc: 1.0000 - val_loss: 0.0123 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 10/20
# 4195/4195 [==============================] - 196s 47ms/step - loss: 6.5362e-06 - acc: 1.0000 - val_loss: 0.0125 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 11/20
# 4195/4195 [==============================] - 197s 47ms/step - loss: 5.3667e-06 - acc: 1.0000 - val_loss: 0.0127 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 12/20
# 4195/4195 [==============================] - 197s 47ms/step - loss: 4.6776e-06 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 13/20
# 4195/4195 [==============================] - 196s 47ms/step - loss: 4.0587e-06 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 14/20
# 4195/4195 [==============================] - 196s 47ms/step - loss: 3.2697e-06 - acc: 1.0000 - val_loss: 0.0132 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 15/20
# 4195/4195 [==============================] - 196s 47ms/step - loss: 2.8234e-06 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 16/20
# 4195/4195 [==============================] - 196s 47ms/step - loss: 2.6245e-06 - acc: 1.0000 - val_loss: 0.0134 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 17/20
# 4195/4195 [==============================] - 197s 47ms/step - loss: 2.1888e-06 - acc: 1.0000 - val_loss: 0.0135 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 18/20
# 4195/4195 [==============================] - 196s 47ms/step - loss: 1.9933e-06 - acc: 1.0000 - val_loss: 0.0136 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 19/20
# 4195/4195 [==============================] - 195s 47ms/step - loss: 1.6253e-06 - acc: 1.0000 - val_loss: 0.0136 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Epoch 20/20
# 4195/4195 [==============================] - 196s 47ms/step - loss: 1.5276e-06 - acc: 1.0000 - val_loss: 0.0137 - val_acc: 0.9981
# val_f1:0.98	val_precision: 1.0	val_recall: 0.96
#
# Elapsed time (learning): 01:07:24

# %% [markdown]
# ### Plot loss

# %%
history_dict = history.history

acc = history_dict['acc']
val_acc = history_dict['val_acc']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12,12))
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
# ### Plot accuracy

# %%
plt.figure(figsize=(12,12))
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'g', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Plot precision (for matching records)

# %%
plt.figure(figsize=(12,12))
valPrecision = metricsHistory.valPrecisionHistory
plt.plot(epochs, valPrecision, 'g', label='Validation precision')
plt.title('Validation precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()

# %% [markdown]
# ### Plot recall (for matching records)

# %%
plt.figure(figsize=(12,12))
valRecall = metricsHistory.valRecallHistory
plt.plot(epochs, valRecall, 'g', label='Validation recall')
plt.title('Validation recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()

# %% [markdown]
# ### Plot F-measure (for matching records)

# %%
plt.figure(figsize=(12,12))
valFMeasure = metricsHistory.valFMeasureHistory
plt.plot(epochs, valFMeasure, 'g', label='Validation f-measure')
plt.title('Validation f-measure')
plt.xlabel('Epochs')
plt.ylabel('F-measure')
plt.legend()

# %% [markdown]
# ### Evaluating the model trained on 20 epoch
#
# ### Predict labels on test data

# %%
predictedLabels = model.predict(x=[leftTableTestData, rightTableTestData])
predictedBinaryLabels = predictedLabels.argmax(axis=1)
testBinaryLabels = testLabels.argmax(axis=1)

# %% [markdown]
# ### Compute confusion matrix

# %%
cm = confusion_matrix(testBinaryLabels, predictedBinaryLabels)
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(cm, annot=True, ax = ax, fmt='g', cmap='Blues')

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['non matching', 'matching'])
ax.yaxis.set_ticklabels(['non matching', 'matching'])
# Out:
# [Text(0, 0.5, 'non matching'), Text(0, 1.5, 'matching')]

# %% [markdown]
# ### Compute metrics

# %%
precisionValues, recallValues, fMeasureValues, supportValues = precision_recall_fscore_support(testBinaryLabels, predictedBinaryLabels)

NUM_LABELS = len(precisionValues)

row_format ="{:>15}" * 5
print(row_format.format('Label','Precision', 'Recall', 'F-measure', 'Support'))

for i in range(NUM_LABELS):
    fMeasure = fMeasureValues[i]
    
    if fMeasure is None:
        fMeasure = 0.0
        
    print(row_format.format(i, round(precisionValues[i], 2), round(recallValues[i], 2), round(fMeasureValues[i],2), round(supportValues[i],2)))
# Out:
#           Label      Precision         Recall      F-measure        Support
#               0            1.0            1.0            1.0            501
#               1            1.0            1.0            1.0             23

# %% [markdown]
# ---
#
# ### Evaluating the "best" model
#
# ### Loading the model

# %%
bestModel = load_model('best-model.h5')

# %% [markdown]
# ### Predict labels on test data

# %%
predictedLabels = bestModel.predict(x=[leftTableTestData, rightTableTestData])
predictedBinaryLabels = predictedLabels.argmax(axis=1)

# %% [markdown]
# ### Compute confusion matrix

# %%
cm = confusion_matrix(testBinaryLabels, predictedBinaryLabels)
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(cm, annot=True, ax = ax, fmt='g', cmap='Blues')

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['non matching', 'matching'])
ax.yaxis.set_ticklabels(['non matching', 'matching'])
# Out:
# [Text(0, 0.5, 'non matching'), Text(0, 1.5, 'matching')]

# %% [markdown]
# ### Compute metrics

# %%
precisionValues, recallValues, fMeasureValues, supportValues = precision_recall_fscore_support(testBinaryLabels, predictedBinaryLabels)

print(row_format.format('Label','Precision', 'Recall', 'F-measure', 'Support'))

for i in range(NUM_LABELS):
    fMeasure = fMeasureValues[i]
    
    if fMeasure is None:
        fMeasure = 0.0
        
    print(row_format.format(i, round(precisionValues[i], 2), round(recallValues[i], 2), round(fMeasureValues[i],2), round(supportValues[i],2)))
# Out:
#           Label      Precision         Recall      F-measure        Support
#               0            1.0            1.0            1.0            501
#               1            1.0            1.0            1.0             23
